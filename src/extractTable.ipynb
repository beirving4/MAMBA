# %%
import numpy as np
import camelot 
import pandas as pd

# %%
tablesUM = pd.read_html("https://academic.oup.com/view-large/138467902")
tablesUM
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/bryen/Documents/Physics Research/Stanford/MAMBA/src/extractTable.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/bryen/Documents/Physics%20Research/Stanford/MAMBA/src/extractTable.ipynb#ch0000001?line=0'>1</a> tablesUM = pd.read_html("https://academic.oup.com/view-large/138467902")
#       <a href='vscode-notebook-cell:/Users/bryen/Documents/Physics%20Research/Stanford/MAMBA/src/extractTable.ipynb#ch0000001?line=1'>2</a> tablesUM
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/bryen/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
# ...
